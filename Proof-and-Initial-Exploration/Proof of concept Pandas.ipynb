# %%
##Importing Pandas and Nunpy
import pandas as pd
import numpy as np

# %%
##Importing only the columns that I need
col_list = ["Date", "HomeTeam","AwayTeam","FTHG","FTAG","B365H","B365D","B365A"]
df = pd.read_csv("2019_2020.csv", usecols=col_list)

# %%
upsets = 0
non_upsets = 0
starting_bankroll = 500
wagering_size = 25

# %%
bankroll = starting_bankroll

# %%
df
# Out:
#            Date        HomeTeam          AwayTeam  FTHG  FTAG  B365H  B365D  \
# 0    09/08/2019       Liverpool           Norwich     4     1   1.14  10.00
# 1    10/08/2019        West Ham          Man City     0     5  12.00   6.50
# 2    10/08/2019     Bournemouth  Sheffield United     1     1   1.95   3.60
# 3    10/08/2019         Burnley       Southampton     3     0   2.62   3.20
# 4    10/08/2019  Crystal Palace           Everton     0     0   3.00   3.25
# ..          ...             ...               ...   ...   ...    ...    ...
# 375  26/07/2020       Leicester        Man United     0     2   3.25   3.50
# 376  26/07/2020        Man City           Norwich     5     0   1.08  11.00
# 377  26/07/2020       Newcastle         Liverpool     1     3   7.50   5.25
# 378  26/07/2020     Southampton  Sheffield United     3     1   2.15   3.50
# 379  26/07/2020        West Ham       Aston Villa     1     1   3.00   3.60
#
#      B365A
# 0    19.00
# 1     1.22
# 2     3.60
# ...

# %%
df.dtypes
# Out:
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
# FTAG          int64
# B365H       float64
# B365D       float64
# B365A       float64
# dtype: object

# %%
df['HomeDog'] = np.where(df['B365H'] > df['B365A'], 1, 0)
df.head()
# Out:
#          Date        HomeTeam          AwayTeam  FTHG  FTAG  B365H  B365D  \
# 0  09/08/2019       Liverpool           Norwich     4     1   1.14  10.00
# 1  10/08/2019        West Ham          Man City     0     5  12.00   6.50
# 2  10/08/2019     Bournemouth  Sheffield United     1     1   1.95   3.60
# 3  10/08/2019         Burnley       Southampton     3     0   2.62   3.20
# 4  10/08/2019  Crystal Palace           Everton     0     0   3.00   3.25
#
#    B365A  HomeDog
# 0  19.00        0
# 1   1.22        1
# 2   3.60        0
# 3   2.75        0
# 4   2.37        1

# %%
for i, row in df.iterrows():
    if row['B365H'] > row['B365A']:
        if row['FTHG'] > row['FTAG']:
            upsets += 1
            bankroll += wagering_size * (row['B365H']-1)
        else:
            non_upsets += 1
            bankroll -= wagering_size

# %%
ROI = ((bankroll - starting_bankroll) / (wagering_size * (upsets + non_upsets))) * 100

print ("There were '%s' upsets out of '%s' total matches" % (upsets, upsets + non_upsets))
print ("Starting bankroll = '%s'" % (starting_bankroll))
print ("Finishing bankroll = '%s' | ROI = '%s'" % (bankroll, ROI))
# Out:
# There were '38' upsets out of '134' total matches
# Starting bankroll = '500'
# Finishing bankroll = '1376.25' | ROI = '26.15671641791045'

# %%
print (non_upsets)
# Out:
# 1
